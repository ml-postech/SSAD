# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.font_manager as fm
# %matplotlib inline 


data_to_plot = [np_data_1, np_data_2, np_data_3, np_data_4, np_data_5, np_data_6]

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,1,1])
# ax.set_yscale("log")
ax.set_xticks([])
ax.set_ylabel("Anomaly Score", size=18)

labels = []
pad = 0.5
x_positions = [1, 2, 3 + pad, 4 + pad]
# x_positions = [1, 2, 3 + pad, 4 + pad, 5 + 2 * pad, 6 + 2 * pad,]

# Create the boxplot
for i in range(4):
    vp = ax.violinplot([data_to_plot[i]], positions=[x_positions[i]], showmeans=True)
    color = vp["bodies"][0].get_facecolor().flatten()
    labels.append((mpatches.Patch(color=color), data_labels2[i]))

plt.rc('legend', fontsize=1)
fig.legend(*zip(*labels), loc=9)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.font_manager as fm
# %matplotlib inline 


data_to_plot = [np_data_1, np_data_2]

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,1,1])
# ax.set_yscale("log")
ax.set_xticks([])
ax.set_ylabel("Anomaly Score", size=18)

labels = []
pad = 0.5
x_positions = [1, 2]
# x_positions = [1, 2, 3 + pad, 4 + pad, 5 + 2 * pad, 6 + 2 * pad,]

# Create the boxplot
for i in range(2):
    vp = ax.violinplot([data_to_plot[i]], positions=[x_positions[i]], showmeans=True)
    color = vp["bodies"][0].get_facecolor().flatten()
    labels.append((mpatches.Patch(color=color), data_labels2[i]))

plt.rc('legend', fontsize=10)
fig.legend(*zip(*labels), loc=9)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.font_manager as fm
# %matplotlib inline 


data_to_plot = [np_data_3, np_data_4]

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,1,1])
# ax.set_yscale("log")
ax.set_xticks([])
ax.set_ylabel("Anomaly Score", size=18)

labels = []
pad = 0.5
x_positions = [1, 2]
# x_positions = [1, 2, 3 + pad, 4 + pad, 5 + 2 * pad, 6 + 2 * pad,]

# Create the boxplot
for i in range(2):
    vp = ax.violinplot([data_to_plot[i]], positions=[x_positions[i]], showmeans=True)
    color = vp["bodies"][0].get_facecolor().flatten()
    labels.append((mpatches.Patch(color=color), data_labels2[i+2]))

plt.rc('legend', fontsize=10)
fig.legend(*zip(*labels), loc=9)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.font_manager as fm
# %matplotlib inline 


data_to_plot = [np_data_1, np_data_2, np_data_3, np_data_4, np_data_5, np_data_6]

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,1,1])
ax.set_yscale("log")
ax.set_xticks([])
ax.set_ylabel("Anomaly Score", size=18)

labels = []
pad = 0.5
x_positions = [1, 2, 3 + pad, 4 + pad, 5 + 2 * pad, 6 + 2 * pad,]

# Create the boxplot
for i in range(6):
    vp = ax.violinplot([data_to_plot[i]], positions=[x_positions[i]], showmeans=True)
    color = vp["bodies"][0].get_facecolor().flatten()
    labels.append((mpatches.Patch(color=color), data_labels[i]))

plt.rc('legend', fontsize=16)
fig.legend(*zip(*labels), loc=9)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.font_manager as fm
# %matplotlib inline 


data_to_plot = [np_data_1, np_data_2, np_data_3, np_data_4, np_data_5, np_data_6]

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,1,1])
ax.set_yscale("log")
ax.set_xticks([])
ax.set_ylabel("Anomaly Score", size=18)

labels = []
pad = 0.5
x_positions = [1, 2, 3 + pad, 4 + pad]

# Create the boxplot
for i in range(4):
    vp = ax.violinplot([data_to_plot[i]], positions=[x_positions[i]], showmeans=True)
    color = vp["bodies"][0].get_facecolor().flatten()
    labels.append((mpatches.Patch(color=color), data_labels[i]))

plt.rc('legend', fontsize=5)
fig.legend(*zip(*labels), loc=9)
plt.show()
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
data_to_plot = [np_data_1, np_data_2, np_data_3, np_data_4, np_data_5, np_data_6]

# Create a figure instance
fig = plt.figure()

# Create an axes instance
ax = fig.add_axes([0,0,1,1])
# ax.set_yscale("log")
ax.set_xticks([])
ax.set_ylabel("anomaly score", size=18)

labels = []
pad = 0.5
x_positions = [1, 2, 3 + pad, 4 + pad, 5 + 2 * pad, 6 + 2 * pad,]

# Create the boxplot
for i in range(4):
    print(np.mean(data_to_plot[i]))
    vp = ax.violinplot([data_to_plot[i]], positions=[x_positions[i]], showmeans=True)
    color = vp["bodies"][0].get_facecolor().flatten()
    labels.append((mpatches.Patch(color=color), data_labels[i]))

# fig.legend(*zip(*labels), loc=9)
plt.show()
# Out:
# 9.48783640512605
# 11.875193925462185
# 10.59958813352
# 12.493122067142858

# %%
import pandas as pd
df = pd.DataFrame({'original X-UMX': [4.51, -0.9, 2.93, 1.459],'informed X-UMX': [10.17, 6.85, 7.23, 6.34]})
machine = ['valve 1', 'valve 2', 'slide rail 1',' slide rail 2']

# Create a figure instance
fig, ax = plt.subplots(figsize=(12, 8))

bar_width = 0.25
index = np.arange(4)
b1 = plt.bar(index, df['original X-UMX'] + 2, bar_width, alpha=0.4, color='tab:blue', label='original X-UMX', bottom=-2)
b2 = plt.bar(index + bar_width, df['informed X-UMX'] + 2, bar_width, alpha=0.4, color='tab:orange', label='informed X-UMX', bottom=-2)
plt.xticks(np.arange(bar_width, 4 + bar_width, 1), machine)

for rect in b1:
    height = rect.get_height() - 2
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 24)
    
for rect in b2:
    height = rect.get_height() - 2
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 24)
plt.xlabel('machine', size = 32, labelpad = 20)
plt.ylabel('SDR', size = 32)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.rc('legend', fontsize=28)
plt.ylim(-2, 12)
plt.legend()
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'original X-UMX': [1.18, 1.02],'original X-UMX + PIT': [2.01, 1.74],'informed X-UMX': [7.13, 7.41]})
machine = ['valve', 'slide rail']

# Create a figure instance
fig, ax = plt.subplots(figsize=(12, 8))

bar_width = 0.25
index = np.arange(2)
b1 = plt.bar(index, df['original X-UMX'] + 2, bar_width, alpha=0.4, color='tab:blue', label='original X-UMX', bottom=-2)
b2 = plt.bar(index + bar_width, df['original X-UMX + PIT'] + 2, bar_width, alpha=0.4, color='tab:green', label='original X-UMX + PIT', bottom=-2)
b3 = plt.bar(index + bar_width * 2, df['informed X-UMX'] + 2, bar_width, alpha=0.4, color='tab:orange', label='informed X-UMX', bottom=-2)
plt.xticks(np.arange(bar_width, 4 + bar_width, 1), machine)

for rect in b1:
    height = rect.get_height() - 2
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 24)
    
for rect in b2:
    height = rect.get_height() - 2
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 24)
    
for rect in b3:
    height = rect.get_height() - 2
    plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.1f' % height, ha='center', va='bottom', size = 24)
plt.xlabel('machine', size = 28, labelpad = 20)
plt.ylabel('SDR', size = 28)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.rc('legend', fontsize=24)
plt.xlim(-0.5, 2)
plt.ylim(-1, 12)
plt.legend()
plt.show()

# %%
oracle = [0.670,0.670,0.670,0.670,0.670]
mixture_error_mean = [0.593, 0.56616, 0.54435]
mixture_error_max = [0.61649, 0.59351, 0.57219]
proposed_error_mean = [0.694,0.66677,0.62496]
proposed_error_max = [0.90407,0.66322,0.63376 ]

# Create a figure instance
fig, ax = plt.subplots(figsize=(12, 8))
plt.grid(True, axis='y')

plt.plot(range(-1, 4),oracle, label='oracle baseline', linestyle='--')
plt.plot(mixture_error_mean, label='mixture baseline', marker='o')
plt.plot(proposed_error_mean, label='SSAD', marker='o')
plt.xticks([0, 1, 2], [2, 3, 4])

for i in range(3):
    label = "{:.3f}".format(mixture_error_mean[i])
    plt.annotate(label, (i,mixture_error_mean[i]+0.01), ha='center', fontsize=20)
    
    label = "{:.3f}".format(proposed_error_mean[i])
    plt.annotate(label, (i,proposed_error_mean[i]+0.01), ha='center', fontsize=20)


plt.xlabel('# of sources', size = 28, labelpad = 20)
plt.ylabel('AUC', size = 28)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.rc('legend', fontsize=24)
plt.xlim(-0.5, 2.5)
plt.ylim(0.5, 0.8)
plt.legend()
plt.show()

# %%
oracle = [0.670,0.670,0.670,0.670,0.670]
oracle_mask = [0.827,0.827,0.827,0.827,0.827]

mixture_error_mean = [0.593, 0.509, 0.518]
mixture_mask_mean = [0.669,0.622, 0.595]

mixture_errorbar = [0.021, 0.011, 0.016]
mixture_mask_errorbar = [0.025, 0.017, 0.009]

proposed_error_mean = [0.694,0.643, 0.667]
ssad_mask_mean = [0.724,0.717, 0.747]

ssad_errorbar = [0.009, 0.020, 0.026]
ssad_mask_errorbar = [0.025, 0.016, 0.012]



# Create a figure instance
fig, ax = plt.subplots(figsize=(12, 8))
# plt.grid(True, axis='y')

plt.plot(range(-1, 4),oracle, label='oracle, no mask', linestyle='-', color='black')
plt.plot(range(-1, 4),oracle_mask, label='oracle', linestyle='dashdot', color='black')

# plt.plot(mixture_error_mean, label='mixture baseline', marker='o', color='tab:red')
marks, caps, bars = plt.errorbar(range(3), mixture_error_mean, mixture_errorbar, label='mixture, no mask', 
             marker='o', color='tab:red', 
             capsize=5)
[cap.set_alpha(0.5) for cap in caps]
[bar.set_alpha(0.5) for bar in bars]

# plt.plot(mixture_mask_mean, label='mixture baseline + mask', marker='o', linestyle='dashdot', color='tab:red')
marks, caps, bars = plt.errorbar(range(3), mixture_mask_mean, mixture_mask_errorbar, label='mixture',
             marker='o', linestyle='dashdot', color='tab:red', 
             capsize=10)
[cap.set_alpha(0.5) for cap in caps]
[bar.set_alpha(0.5) for bar in bars]

# plt.plot(proposed_error_mean, label='SSAD', marker='^', color='tab:green', markersize=8)
marks, caps, bars = plt.errorbar(range(3), proposed_error_mean, ssad_errorbar, label='separated, no mask', 
             marker='^', color='blue', markersize=8,
             capsize=5)
[cap.set_alpha(0.5) for cap in caps]
[bar.set_alpha(0.5) for bar in bars]

# plt.plot(ssad_mask_mean, label='SSAD + mask', marker='^', linestyle='dashdot', color='tab:green', markersize=8)
marks, caps, bars = plt.errorbar(range(3), ssad_mask_mean, ssad_mask_errorbar, label='separated', 
             marker='^', color='blue', markersize=8, linestyle='dashdot',
             capsize=10)
[cap.set_alpha(0.5) for cap in caps]
[bar.set_alpha(0.5) for bar in bars]

plt.xticks([0, 1, 2], [2, 3, 4])

# for i in range(3):
#     label = "{:.3f}".format(mixture_error_mean[i])
#     plt.annotate(label, (i,mixture_error_mean[i]-0.02), ha='center', fontsize=20)
    
#     label = "{:.3f}".format(proposed_error_mean[i])
#     plt.annotate(label, (i,proposed_error_mean[i]+0.01), ha='center', fontsize=20)
    
#     label = "{:.3f}".format(mixture_mask_mean[i])
#     plt.annotate(label, (i,mixture_mask_mean[i]-0.02), ha='center', fontsize=20)

#     label = "{:.3f}".format(ssad_mask_mean[i])
#     plt.annotate(label, (i,ssad_mask_mean[i]+0.01), ha='center', fontsize=20)



plt.xlabel('the number of sources', size = 28, labelpad = 20)
plt.ylabel('AUC', size = 28)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.rc('legend', fontsize=20)
plt.xlim(-0.5, 2.5)
plt.ylim(0.45, 0.90)
plt.legend(loc='upper center', prop={'size': 20}, ncol=3, bbox_to_anchor=(0.5, 1.2))
plt.show()

# %%
import pickle

with open('/hdd/hdd1/kjc/tmp/overlap_mix_slider02.pkl', 'rb') as f:
    data = pickle.load(f) 
    
normal = []
machine_type = []
mean_error = []
max_error = []
overlap = []

for line in data:
    normal.append(line[0])
    machine_type.append(line[1])
    mean_error.append(line[2])
    max_error.append(line[3])
    overlap.append(line[4])

# %%
fig = plt.figure()
colors = ['b' if n == 'normal' else ('r' if i == 'id_00' else 'g') for n, i in zip(normal, machine_type)]
plt.scatter(overlap, mean_error, s=1, c=colors)
plt.show()

# %%
from sklearn import metrics
y_true = np.array([0 if n == 'normal' else 1 for n in normal])
mean_score = metrics.roc_auc_score(y_true, np.array(mean_error))
max_score = metrics.roc_auc_score(y_true, np.array(max_error))
print(mean_score)
print(max_score)
# Out:
# 0.9570914927768861
# 0.9657142857142857

# %%
import pickle

with open('/hdd/hdd1/kjc/tmp/overlap_sep_slider02_shift2.pkl', 'rb') as f:
# with open('/hdd/hdd1/kjc/tmp/overlap_sep_slider02.pkl', 'rb') as f:
    data = pickle.load(f) 
    
normal = []
machine_type = []
sdr = []
mean_error = []
max_error = []
overlap = []

for line in data:
    normal.append(line[0])
    machine_type.append(line[1])
    sdr.append(line[2])
    mean_error.append(line[3])
    max_error.append(line[4])
    overlap.append(line[5])

# %%
fig = plt.figure()
colors = [('b' if i == 'id_00' else 'k') if n == 'normal' else ('r' if i == 'id_00' else 'g') for n, i in zip(normal, machine_type)]
plt.scatter(sdr, mean_error, s=1, c=colors)
plt.show()

# %%
fig = plt.figure()
overlap_normal = list(map(lambda x : x[0], filter(lambda x : x[1] == 'normal', zip(overlap, normal))))
sdr_normal = list(map(lambda x : x[0], filter(lambda x : x[1] == 'normal', zip(sdr, normal))))
error_normal = list(map(lambda x : x[0], filter(lambda x : x[1] == 'normal', zip(mean_error, normal))))
machine_normal = list(map(lambda x : x[0], filter(lambda x : x[1] == 'normal', zip(machine_type, normal))))

colors = [('b' if i == 'id_00' else 'r') for i in machine_normal]
plt.scatter(overlap_normal, error_normal, s=1, c=colors)
plt.show()

# %%
param1 = overlap
param2 = mean_error

a = list(map(lambda x : x[1], filter(lambda x : x[0] > 0 and x[0] < 0.2 and x[2] == 'normal', zip(param1, param2, normal))))
print(sum(a) / len(a))

a = list(map(lambda x : x[1], filter(lambda x : x[0] > 0.2 and x[0] < 0.4 and x[2] == 'normal', zip(param1, param2, normal))))
print(sum(a) / len(a))

a = list(map(lambda x : x[1], filter(lambda x : x[0] > 0.4 and x[0] < 0.6 and x[2] == 'normal', zip(param1, param2, normal))))
print(sum(a) / len(a))

a = list(map(lambda x : x[1], filter(lambda x : x[0] > 0.6 and x[0] < 0.8 and x[2] == 'normal', zip(param1, param2, normal))))
print(sum(a) / len(a))

a = list(map(lambda x : x[1], filter(lambda x : x[0] > 0.8 and x[2] == 'normal' , zip(param1, sdr, normal))))
print(sum(a) / len(a))
# Out:
# 29.218819773009933
# 28.78832977809263
# 27.112252996208962
# 26.65580670973834
# 5.905858234959603

# %%
print(sum([1 if i == 'id_02' and n == 'normal' else 0 for n, i in zip(normal, machine_type)]))
# Out:
# 200
